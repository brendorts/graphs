# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import FormatStrFormatter
data = pd.read_csv('traza.csv')

# %%
palette = ['#FFFF00','#A8CF45','#0080FF','#FF7EC0', '#F58634']
sns.set_palette(palette, n_colors=5, color_codes=True)
sns.color_palette()
# Out:
# [(1.0, 1.0, 0.0),
#  (0.6588235294117647, 0.8117647058823529, 0.27058823529411763),
#  (0.0, 0.5019607843137255, 1.0),
#  (1.0, 0.49411764705882355, 0.7529411764705882),
#  (0.9607843137254902, 0.5254901960784314, 0.20392156862745098)]

# %%
# Define your hex color codes
hex_palette = ['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0']

# Set the color palette using the defined hex values
sns.set_palette(sns.color_palette(hex_palette))
sns.color_palette()
# Now you can use seaborn plotting functions, and they will use the defined color palette
# Out:
# [(0.6588235294117647, 0.8117647058823529, 0.27058823529411763),
#  (0.9607843137254902, 0.5254901960784314, 0.20392156862745098),
#  (1.0, 1.0, 0.0),
#  (1.0, 0.49411764705882355, 0.7529411764705882)]

# %%
datos = pd.read_csv('traza.csv')

# %%
print(datos)
# Out:
#       Locality Sample    Spot           Mg           Al           Si  \
# 0    Lachitova     J8    J8-1   822.525475   463.839383  2167.751346
# 1    Lachitova     J8    J8-2   870.052800   477.161076  1870.648532
# 2    Lachitova     J8    J8-3  1093.114442   432.395951   953.423454
# 3    Lachitova     J8    J8-4  1335.479182   426.516648  2343.253110
# 4    Lachitova     J8    J8-5   667.712362   659.356216  2048.401867
# ..         ...    ...     ...          ...          ...          ...
# 79  Las Cuevas    J41   J41-7  1132.437779  1627.722355   541.035040
# 80  Las Cuevas    J41   J41-8  1576.789372  1378.954449   960.798590
# 81  Las Cuevas    J41   J41-9   791.283866  3447.732640   621.247072
# 82  Las Cuevas    J41  J41-10  3935.602994  1057.363877  1101.350757
# 83  Las Cuevas    J41  J41-11  1056.755603  2722.308407          NaN
#
#             P          Ca          Ti          V  ...          Co         Ni  \
# ...

# %%
plt.figure(figsize=(6,7))
plt.grid(True, linestyle=':', alpha=0.5) 
nadoll=sns.scatterplot(x="Ni", y="Co", s=100, data=data, hue="Locality", palette=['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0'], 
                       alpha=0.8, edgecolor="white")
#s: escalar
#plt.xscale('log')
#plt.yscale('log')
#plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
#plt.legend(title='Localidad', loc='lower right', ncol=2)
#plt.xlim(0.0001,10)
#plt.ylim(0.001,10)
#plt.xlabel("Ti+V(wt.%)")
#plt.ylabel("Al+Mn(wt.%)")
#plt.savefig("abc.png", dpi=300)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

#plt.figure(figsize=(6,7))
plt.grid(True, linestyle=':', alpha=0.5) 

g1=sns.scatterplot(ax=axes[0, 0], x="Ni", y="Co", s=100, data=data, hue="Locality", palette=['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0'], 
                       alpha=0.8, edgecolor="white")
g1.set_yscale('log')
g1.set_xscale('log')
g1.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
g1.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
#g1.set_xlim(0.1, 100)
#g1.xlim(1,100)

#g1.set_title("Mg", fontweight='bold', fontsize=16)
#g1.set_xlabel("  ")
#g1.set_xticklabels([])
#g1.tick_params(axis='y', labelsize=14)
#g1.set_ylabel('ppm', fontsize=14)
g1.get_legend().remove()
#g1.tick_params(bottom=False)

g2=sns.scatterplot(ax=axes[0, 1], x="Ti", y="Mg", s=100, data=data, hue="Locality", palette=['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0'], 
                       alpha=0.8, edgecolor="white")
g2.set_yscale('log')
g2.set_xscale('log')
g2.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
g2.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
g2.get_legend().remove()

g3=sns.scatterplot(ax=axes[1, 0], x="Ti", y="Al", s=100, data=data, hue="Locality", palette=['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0'], 
                       alpha=0.8, edgecolor="white")
g3.set_yscale('log')
g3.set_xscale('log')
g3.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
g3.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))
g3.get_legend().remove()

g4=sns.scatterplot(ax=axes[1, 1], x="Al", y="Ga", s=100, data=data, hue="Locality", palette=['#A8CF45', '#F58634', '#FFFF00', '#FF7EC0'], 
                       alpha=0.8, edgecolor="white")
g4.set_yscale('log')
g4.set_xscale('log')
g4.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
g4.yaxis.set_major_formatter(FormatStrFormatter('%.0f'))

plt.tight_layout()
plt.show()
#s: escalar
#plt.xscale('log')
#plt.yscale('log')
#plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
#plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
#plt.legend(title='Localidad', loc='lower right', ncol=2)
#plt.xlim(0.0001,10)
#plt.ylim(0.001,10)
#plt.xlabel("Ti+V(wt.%)")
#plt.ylabel("Al+Mn(wt.%)")
#plt.savefig("abc.png", dpi=300)

# %%
#plot_file_name="nadoll.jpg"
#guardamos como formato jpeg
#nadoll.figure.savefig(plot_file_name,
                    format='jpg',
                    dpi=100)
